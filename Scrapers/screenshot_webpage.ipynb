# %%
def Screenshot_webpage(URL):
    from time import sleep
    from selenium import webdriver
    from PIL import Image
    from selenium import webdriver
    from Screenshot import Screenshot_Clipping
    browser = webdriver.Chrome()
    browser.get(URL)
    browser.save_screenshot('ss.png')
    screenshot = Image.open('ss.png')
    screenshot.show()

# %%
Screenshot_webpage('https://www.postandcourier.com/business/real_estate/2-new-charleston-area-restaurants-on-the-way-as-gastro-pub-closes-9-months-after/article_f9ceb5ee-d399-11ec-9009-8fdc0fc34d88.html#tncms-source=article-nav-next')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1905x1067 at 0x7FA76FA07EB8>

# %%
from Screenshot import Screenshot_Clipping

# %%
import Screenshot
